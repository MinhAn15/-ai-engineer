# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie'],
    'age': [25, 30, 35],
    'city': ['NYC', 'LA', 'Chicago']
})

# %%
# df = pd.read_csv('data.csv')  # nếu có file CSV

# %%
print(df.head())        # 5 dòng đầu
print(df.info())        # kiểu dữ liệu, số missing
print(df.describe())     # thống kê cơ bản
print(df.shape)         # số hàng, số cột
print(df.columns)      # tên cột
print(df.dtypes)        # kiểu từng cột
